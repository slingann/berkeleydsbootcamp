# %%
import numpy as np
import math
from datascience import *

# %% [markdown]
# # Welcome to Deepnote!
#
# **Today's Agenda:**
#
# 1. Learn how to run and use Deepnote on your laptop
# 2. Learn about what the data science module is
# 3. Master the basics of Python

# %% [markdown]
# ## Section 1: Deepnote Notebook Shortcuts

# %% [markdown]
# ### Running Code

# %% [markdown]
# To run a block of code, click the button that says `▶| Run` on the Right of the block or hold down `shift` + `return`. The next block of code should output a message using the **print** function. Assign the "name" variable to your name and run the code.

# %%
name = "Samiksha" #inside the quotes, put down your name!
print("Congrats " + name + "! You have successfully run a block of code :)")
# Out:
# Congrats Samiksha! You have successfully run a block of code :)

# %% [markdown]
# To delete a block of code, click the trashcan to the right of the cell.
#
# To add a block of code below the current cell, hover over the space in between cells where you want to insert a new cell, press "+ Code".
#
# To add a block of text below the current cell, hover over the space in between cells where you want to insert a new cell and press " + Block".

# %%
##delete this cell! add a cell above this one! add a cell below this one! very fun stuff

# %% [markdown]
# ### Cells
#
# The textboxes where you are writing your code are known as cells.
#
# But there are different types of cells that are designed to do different things. A Markdown Cell is a cell that cannot write code, but instead is designed to be a textbox to write stuff in!
#
# What you're reading right now is a Markdown Cells! Double check on this cell to see!

# %%
#This is a Code Cell! You can write code in here!

# %% [markdown]
# ### Outputing Code +  Errors

# %% [markdown]
# When you run a Code Cell (Shift + Enter), if your code is meant to have an output, the output will appear below the cell. Note, even if you are not expecting your code to output anything, you still need to run the code using Shift + Enter!
#
# Example:

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# If your code is **incorrect**, when you run the code it will display an error in **red** as the output!

# %%
print("hi")
# Out:
# hi

# %% [markdown]
# ## Section 2: Math and Variables in Python

# %% [markdown]
# For each Section in the Notebook, we've listed out some key concepts from the slides for you to reference!

# %% [markdown]
# ### Addition / Subtraction

# %%
9 + 10
# Out:
# 19

# %%
-10 + -11
# Out:
# -21

# %%
2 - 1
# Out:
# 1

# %%
-5 - 3
# Out:
# -8

# %% [markdown]
# ### Multiplication / Division

# %%
5 * 9
# Out:
# 45

# %%
20 * 0
# Out:
# 0

# %%
42 / 6
# Out:
# 7.0

# %%
25 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 25 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Modulo Expression (%) - Can be used to find remainder

# %%
10 % 4
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %%
7 % 1
# Out:
# 0

# %%
22 % 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 22 % 0
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# ### Power Expression (**) - Can be used to calculate exponentials

# %%
2 ** 2
# Out:
# 4

# %%
49 ** 0.5        #square root
# Out:
# 7.0

# %% [markdown]
# ### PEMDAS / PERMDAS

# %%
6 / 2 * (1 + 2)
# Out:
# 9.0

# %%
9 - 3 / (1 / 3) + 1
# Out:
# 1.0

# %%
3 ** 2 / 0.5 + 2 * (3.2 - 6.4)
# Out:
# 11.6

# %% [markdown]
# ## Practice with variables

# %%
a = 9
b = 50
c = 76
d = 11
e = 27

# %%
# multiply or divide as many variables as you need to get the value 150
27/9*50

# %%
# add or subtract as many variables as you need variables as you need to get the value 64m

c + d + e - b
# Out:
# 64

# %% [markdown]
# ## Section 3: Strings

# %%
x = "data"
y = "science"
print(x + " " + y)
# Out:
# data science

# %% [markdown]
# ## Functions
# ### Custom Functions

# %%
def mult_by_5(s):
    return s * 5

mult_by_5(5)  # enter a number
# Out:
# 25

# %%
def g(s):
    if s % 3 == 0:
        message = print(str(s) + ' is divisible by 3')
    else:
        message = print(str(s) + ' is not divisible by 3')
        
g(5)  # enter a number
# Out:
# 5 is not divisible by 3

# %% [markdown]
# # Discussion Questions!

# %% [markdown]
# ### Question 1
# Implement a function sign_func which takes in a number x and returns 'Positive' if x is positive, 'Negative' if x is negative and 'Zero' if x is 0.
#
# **sign_func(5)**
# >'Positive'
#
# **sign_func(-4)**
# >'Negative'
#
# **sign_func(0)**
# >'Zero'

# %%
def sign_func(x):
    if x < 0:
        return "Negative!"
    elif x > 0:
        return "Positive!"
    else:
        return "Zero!"

# %%
 print(sign_func(5))
 print(sign_func(-4))
 print(sign_func(0))
# Out:
# Positive!
# Negative!
# Zero!

# %% [markdown]
# ### Question 2
# Given the following functions, what do you expect the function calls to output

# %%
def func(c, d):
    if c == 4:
        return 6
    elif d >= 4:
        return 6 + 7 + c
    else:
        return 25

# %% [markdown]
# - func(10, 10) --> 23

# %% [markdown]
# - func(10, 6) --> 23

# %% [markdown]
# - func(4,6) --> 6

# %% [markdown]
# - func(0,0) --> 25

# %% [markdown]
# ### Question 3 (Is Divisible)
# Define a function that tells you if a number `n` is divisible by some other number `x`.
#
# Hint: If a number `n` is divisible by another number `x`, is there a remainder when you divide n by x? How do we get the remainder in python?
#
# **is_divisible(9, 3)**
# >True
#
# **is_divisible(37, 7)**
# >False

# %%
def is_divisible(n, x):
    if n % x == 0:
        return True
    else:
        return False

# %%
print(is_divisible(9,3))
print(is_divisible(37,7))
# Out:
# True
# False

# %% [markdown]
# ### Question 4 (Absolute Addition)
# Implement the function abs_addition that computes the absolute value of a + the absolute value of b.
# Hint: If a is negative, the absolute value of a is -a. Similarly if b is negative, the absolute value of b is -b.
#
# **abs_addition(-2,-3)**
# >5
# **abs_addition(1, -5)**
# >6

# %%
def abs_addition(a, b):
    if a < 0:
        abs_a = -a
    else:
        abs_a = a
    if b < 0:
        abs_b = -b
    else:
        abs_b = b
    return abs_a + abs_b

# %%
print(abs_addition(-2, -3))#should print 5
print(abs_addition(1, -5))#should print 6
# Out:
# 5
# 6

# %% [markdown]
# ### Question 5 (Two Of Three)
# Write a function that takes in three positive numbers (i, j, k) as arguments and returns the sum of the squares of the two smallest numbers.
#
# For example:
# **two_of_three(3,6,7)**
# >45
# as 3 and 6 are the smallest of the two numbers and 3^2 + 6^2 = 45
# **two_of_three(9, 5, 2)**
# >29

# %%
def two_of_three(i, j, k):
     """Return a*a + b*b, where a and b are the two smallest members of the
    positive numbers i, j, and k.

# %%
print(two_of_three(3, 6, 7))#should print 45
print(two_of_three(9, 5, 2))#should print 29

# %% [markdown]
# ## Question 6a: Computing walking distances
# Melissa is on the corner of 7th Avenue and 42nd Street in Midtown Manhattan, and she wants to know far she'd have to walk to get to Gramercy School on the corner of 10th Avenue and 34th Street.
#
# She can't cut across blocks diagonally, since there are buildings in the way.  She has to walk along the sidewalks.  Using the map below, she sees she'd have to walk 3 avenues (long blocks) and 8 streets (short blocks).  In terms of the given numbers, she computed 3 as the difference between 7 and 10, *in absolute value*, and 8 similarly.
#
# Melissa also knows that blocks in Manhattan are all about 80m by 274m (avenues are farther apart than streets).  So in total, she'd have to walk $(80 \times |42 - 34| + 274 \times |7 - 10|)$ meters to get to the park.
#
# **Question** Fill in the line `num_avenues_away = ...` in the next cell so that the cell calculates the distance Melissa must walk and gives it the name `manhattan_distance`.  Everything else has been filled in for you.  **Use the `abs` function.**

# %%
# Here's the number of streets away:
num_streets_away = abs(...)

# Compute the number of avenues away in a similar way:
num_avenues_away = ...

street_length_m = 80
avenue_length_m = 274

# Now we compute the total distance Melissa must walk.
manhattan_distance = street_length_m * num_streets_away + avenue_length_m * num_avenues_away

# We've included this line so that you see the distance you've computed 
# when you run this cell.  
# You don't need to change it, but you can if you want.
manhattan_distance

# %% [markdown]
# ## Question 6b: General Manhattan Distance
# Now we'll have you write a function that computes the Manhattan distance between two locations. The x and y position of the start location is denoted by x_start, y_start. The x and y position of the end location is denoted by x_end, y_end. To compute the Manhattan distance, remember that streets run north to south (so they are associated with the y coordinate), while the avenues run east to west (so they are associated with the x coordinate). Try to match the pattern from the example above!

# %%
 def compute_distance(x_start, y_start, x_end, y_end):
    street_length = 80
    avenue_length = 274
    num_streets_away = abs(...)
    num_avenues_away = abs(...)
    total_distance = (street_length * ....) + (avenue_length * ...)
    return total_distance

print(compute_distance(42, 7, 34, 10)) #you should get the same result as before

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cc0e01a6-8b6d-4be5-bd52-36ae9e1c9b60' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
